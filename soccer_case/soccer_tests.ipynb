# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import utils
from itertools import product
import scipy.io as scio

# %matplotlib notebook

# %%
data = scio.loadmat('soccer/train_data_t_0.10.mat')
x = data['states']
y = data['values']

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(projection='3d')

# [ax.scatter(x[100*i:100*(i+1), 0], x[100*i:100*(i+1), -1], y[100*i:100*(i+1)]) for i in range(1000)]
ax.scatter(x[:, 4], x[:, -1], y)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
x[100:200, 0]
# Out:
# array([0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
#        0.03032863, 0.03032863, 0.03032863, 0.03032863, 0.03032863,
# ...

# %%
A = np.array([[1, 2], [3, 4], [7, 8], [9, 10]])

# %%
A = np.random.rand(12, 2)

# %%
repetitions = np.ones(4, dtype=int)
repetitions[1::2
           ] = 2  # Set repeat_times for every 2nd row

# Repeat the rows
result_array = np.repeat(A, repetitions, axis=0)

# %%
result_array
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [ 3,  4],
#        [ 7,  8],
#        [ 9, 10],
#        [ 9, 10]])
